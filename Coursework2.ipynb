# %% [markdown]
# <a href="https://colab.research.google.com/github/inf7m/IOT-CW2-GGCB/blob/main/Coursework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install azure-iot-device
# Out:
# Collecting azure-iot-device
#   Downloading azure_iot_device-2.14.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: urllib3<3.0.0,>=2.2.2 in /usr/local/lib/python3.13/dist-packages (from azure-iot-device) (2.5.0)
# Requirement already satisfied: deprecation<3.0.0,>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from azure-iot-device) (2.1.0)
# Collecting paho-mqtt<2.0.0,>=1.6.1 (from azure-iot-device)
#   Downloading paho-mqtt-1.6.1.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.13/dist-packages (from azure-iot-device) (2.32.4)
# Collecting requests-unixsocket2>=0.4.1 (from azure-iot-device)
#   Downloading requests_unixsocket2-1.0.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting janus (from azure-iot-device)
#   Downloading janus-2.0.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: PySocks in /usr/local/lib/python3.13/dist-packages (from azure-iot-device) (1.7.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.13/dist-packages (from azure-iot-device) (4.16.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from deprecation<3.0.0,>=2.1.0->azure-iot-device) (26.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.3->azure-iot-device) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.3->azure-iot-device) (3.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.3->azure-iot-device) (2026.7.22)
# Downloading azure_iot_device-2.14.0-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.5/168.5 kB 8.1 MB/s eta 0:00:00
# Downloading requests_unixsocket2-1.0.1-py3-none-any.whl (7.7 kB)
# Downloading janus-2.0.0-py3-none-any.whl (12 kB)
# Building wheels for collected packages: paho-mqtt
#   Building wheel for paho-mqtt (setup.py) ... done
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.6.1-py3-none-any.whl size=62116 sha256=7958e6f1ec479fb0d2bd02fdd77a63dd0c2a72660e374fd6ddfcdae7848189d0
#   Stored in directory: /root/.cache/pip/wheels/f9/58/b1/af83cc69fc3ea9dcfafeb61e26c7fa7bcfca4fdf276791c6dc
# Successfully built paho-mqtt
# Installing collected packages: paho-mqtt, janus, requests-unixsocket2, azure-iot-device
# Successfully installed azure-iot-device-2.14.0 janus-2.0.0 paho-mqtt-1.6.1 requests-unixsocket2-1.0.1

# %%
import asyncio
import json
import random

from azure.iot.device.aio import IoTHubDeviceClient
from azure.iot.device import Message

HOSTNAME = "iotcw2truongdang.azure-devices.net"
DEVICE_ID = "hospital-room-101"
DEVICE_KEY = "hxE1N904zEeOvprg624Po6zYW80AiM9/+UxeU67CaZo="

async def main():
    device = IoTHubDeviceClient.create_from_symmetric_key(
        symmetric_key=DEVICE_KEY,
        hostname=HOSTNAME,
        device_id=DEVICE_ID
    )

    await device.connect()
    print("Connected to Azure IoT Hub!")

    data = {
        "temperature": round(random.uniform(22, 28), 1),
        "humidity": round(random.uniform(40, 70), 1),
        "heartRate": random.randint(60, 100),
        "bedStatus": "occupied"
    }

    message = Message(json.dumps(data))
    message.content_type = "application/json"
    message.content_encoding = "utf-8"

    await device.send_message(message)

    print("Sent:", data)

    await device.shutdown()

await main()
# Out:
# Connected to Azure IoT Hub!
# Sent: {'temperature': 24.4, 'humidity': 53.7, 'heartRate': 69, 'bedStatus': 'occupied'}

# %%
import asyncio
import json
import random
from datetime import datetime

from azure.iot.device.aio import IoTHubDeviceClient
from azure.iot.device import Message

HOSTNAME = "iotcw2truongdang.azure-devices.net"
DEVICE_ID = "hospital-room-101"
DEVICE_KEY = "hxE1N904zEeOvprg624Po6zYW80AiM9/+UxeU67CaZo="


async def main():

    device = IoTHubDeviceClient.create_from_symmetric_key(
        symmetric_key=DEVICE_KEY,
        hostname=HOSTNAME,
        device_id=DEVICE_ID
    )

    await device.connect()

    print("Connected to Azure IoT Hub!\n")

    for i in range(1, 11):

        data = {
            "messageId": i,
            "timestamp": datetime.now().isoformat(timespec="seconds"),
            "temperature": round(random.uniform(22, 28), 1),
            "humidity": round(random.uniform(40, 70), 1),
            "heartRate": random.randint(60, 100),
            "bedStatus": random.choice(["occupied", "empty"])
        }

        message = Message(json.dumps(data))

        message.content_type = "application/json"
        message.content_encoding = "utf-8"

        await device.send_message(message)

        print("Message sent:")
        print(data)
        print()

        await asyncio.sleep(5)

    await device.shutdown()


await main()
# Out:
# Connected to Azure IoT Hub!
#
# Message sent:
# {'messageId': 1, 'timestamp': '2026-09-03T04:50:13', 'temperature': 23.7, 'humidity': 57.2, 'heartRate': 98, 'bedStatus': 'empty'}
#
# Message sent:
# {'messageId': 2, 'timestamp': '2026-09-03T04:50:19', 'temperature': 26.5, 'humidity': 45.7, 'heartRate': 94, 'bedStatus': 'empty'}
#
# Message sent:
# {'messageId': 3, 'timestamp': '2026-09-03T04:50:24', 'temperature': 23.8, 'humidity': 59.6, 'heartRate': 78, 'bedStatus': 'empty'}
#
# Message sent:
# {'messageId': 4, 'timestamp': '2026-09-03T04:50:29', 'temperature': 26.8, 'humidity': 55.0, 'heartRate': 60, 'bedStatus': 'empty'}
#
# Message sent:
# {'messageId': 5, 'timestamp': '2026-09-03T04:50:34', 'temperature': 25.4, 'humidity': 48.6, 'heartRate': 94, 'bedStatus': 'empty'}
#
# Message sent:
# {'messageId': 6, 'timestamp': '2026-09-03T04:50:40', 'temperature': 25.6, 'humidity': 41.5, 'heartRate': 82, 'bedStatus': 'empty'}
#
# Message sent:
# {'messageId': 7, 'timestamp': '2026-09-03T04:50:45', 'temperature': 23.4, 'humidity': 41.6, 'heartRate': 80, 'bedStatus': 'empty'}
#
# Message sent:
# {'messageId': 8, 'timestamp': '2026-09-03T04:50:50', 'temperature': 22.7, 'humidity': 41.5, 'heartRate': 96, 'bedStatus': 'empty'}
#
# Message sent:
# {'messageId': 9, 'timestamp': '2026-09-03T04:50:56', 'temperature': 24.3, 'humidity': 59.7, 'heartRate': 98, 'bedStatus': 'empty'}
#
# Message sent:
# {'messageId': 10, 'timestamp': '2026-09-03T04:51:01', 'temperature': 28.0, 'humidity': 68.7, 'heartRate': 60, 'bedStatus': 'occupied'}

# %%
import json

with open("/content/sample_data/49.json", "r") as file:
    for line in file:
        data = json.loads(line)

        print(data["Body"])
# Out:
# {'temperature': 26.4, 'humidity': 59.4, 'heartRate': 93, 'bedStatus': 'occupied'}
# {'temperature': 24.4, 'humidity': 53.7, 'heartRate': 69, 'bedStatus': 'occupied'}
# {'messageId': 1, 'timestamp': '2026-09-03T04:50:13', 'temperature': 23.7, 'humidity': 57.2, 'heartRate': 98, 'bedStatus': 'empty'}
# {'messageId': 2, 'timestamp': '2026-09-03T04:50:19', 'temperature': 26.5, 'humidity': 45.7, 'heartRate': 94, 'bedStatus': 'empty'}
# {'messageId': 3, 'timestamp': '2026-09-03T04:50:24', 'temperature': 23.8, 'humidity': 59.6, 'heartRate': 78, 'bedStatus': 'empty'}
# {'messageId': 4, 'timestamp': '2026-09-03T04:50:29', 'temperature': 26.8, 'humidity': 55.0, 'heartRate': 60, 'bedStatus': 'empty'}
# {'messageId': 5, 'timestamp': '2026-09-03T04:50:34', 'temperature': 25.4, 'humidity': 48.6, 'heartRate': 94, 'bedStatus': 'empty'}

# %%
import asyncio
import json
import random
from datetime import datetime, timezone

from azure.iot.device.aio import IoTHubDeviceClient
from azure.iot.device import Message


# ============================================================
# AZURE CONFIGURATION
# ============================================================

HOSTNAME = "iotcw2truongdang.azure-devices.net"
DEVICE_ID = "hospital-room-101"
DEVICE_KEY = "hxE1N904zEeOvprg624Po6zYW80AiM9/+UxeU67CaZo="

# PROJECT DATA RANDOM CONFIGURATION

ROOM_ID = "Room-101"

TOTAL_MESSAGES = 20
SEND_INTERVAL_SECONDS = 3



# GENERATE NORMAL SENSOR DATA

def generate_normal_data():

    return {
        "temperature": round(random.uniform(23.0, 27.0), 1),
        "humidity": round(random.uniform(45.0, 65.0), 1),
        "heartRate": random.randint(65, 95),
        "bedStatus": "occupied"
    }


#  RULE FOR ABNORMAL SENSOR DATA *1 for 5

def generate_abnormal_data():

    scenario = random.choice([
        "high_heart_rate",
        "high_temperature",
        "high_humidity"
    ])

    data = generate_normal_data()

    if scenario == "high_heart_rate":
        data["heartRate"] = random.randint(125, 150)

    elif scenario == "high_temperature":
        data["temperature"] = round(
            random.uniform(29.0, 33.0),
            1
        )

    elif scenario == "high_humidity":
        data["humidity"] = round(
            random.uniform(72.0, 85.0),
            1
        )

    return data



# ANALYSE SENSOR DATA

def analyse_sensor_data(data):

    alerts = []

    # Room temperature rule
    if data["temperature"] > 28:
        alerts.append("HIGH TEMPERATURE")

    # Humidity rule
    if data["humidity"] > 70:
        alerts.append("HIGH HUMIDITY")

    # Heart rate rules
    if data["heartRate"] > 120:
        alerts.append("HIGH HEART RATE")

    elif data["heartRate"] < 50:
        alerts.append("LOW HEART RATE")


    # Determine overall status
    if len(alerts) == 0:

        status = "NORMAL"
        alert_message = "NONE"

    else:

        status = "CRITICAL"
        alert_message = " | ".join(alerts)


    return status, alert_message


# CREATE TELEMETRY RECORD TO PUSH INTO AZURE IOT

def build_telemetry(message_id):

    # Every 5th message will intentionally be abnormal
    # This makes the demonstration predictable.
    if message_id % 5 == 0:

        sensor_data = generate_abnormal_data()

        simulation_type = "ABNORMAL"

    else:

        sensor_data = generate_normal_data()

        simulation_type = "NORMAL"


    status, alert = analyse_sensor_data(sensor_data)


    telemetry = {

        "messageId": message_id,

        "deviceId": DEVICE_ID,

        "roomId": ROOM_ID,

        "timestamp": datetime.now(
            timezone.utc
        ).isoformat(),

        "temperature": sensor_data["temperature"],

        "humidity": sensor_data["humidity"],

        "heartRate": sensor_data["heartRate"],

        "bedStatus": sensor_data["bedStatus"],

        "simulationType": simulation_type,

        "status": status,

        "alert": alert
    }


    return telemetry



# CREATE AZURE MESSAGE

def create_azure_message(telemetry):

    message = Message(
        json.dumps(telemetry)
    )

    message.content_type = "application/json"

    message.content_encoding = "utf-8"

    message.message_id = str(
        telemetry["messageId"]
    )

    return message


# DISPLAY TELEMETRY

def print_telemetry(data):

    print("\n========================================")

    print(
        "MESSAGE ID      :",
        data["messageId"]
    )

    print(
        "ROOM            :",
        data["roomId"]
    )

    print(
        "TIMESTAMP       :",
        data["timestamp"]
    )

    print(
        "TEMPERATURE     :",
        data["temperature"],
        "°C"
    )

    print(
        "HUMIDITY        :",
        data["humidity"],
        "%"
    )

    print(
        "HEART RATE      :",
        data["heartRate"],
        "BPM"
    )

    print(
        "BED STATUS      :",
        data["bedStatus"]
    )

    print(
        "SIMULATION TYPE :",
        data["simulationType"]
    )

    print(
        "SYSTEM STATUS   :",
        data["status"]
    )

    print(
        "ALERT           :",
        data["alert"]
    )


# MAIN APPLICATION

async def main():

    print("========================================")
    print(" SMART HOSPITAL IoT MONITORING SYSTEM")
    print("========================================")

    print("\nConnecting to Azure IoT Hub...")


    # --------------------------------------------------------
    # CREATE DEVICE CLIENT
    # --------------------------------------------------------

    device = IoTHubDeviceClient.create_from_symmetric_key(

        symmetric_key=DEVICE_KEY,

        hostname=HOSTNAME,

        device_id=DEVICE_ID,

        product_info="HospitalRoomMonitoringSystem"
    )


    # --------------------------------------------------------
    # CONNECT
    # --------------------------------------------------------

    try:

        await device.connect()

        print(
            "Connected:",
            device.connected
        )

        print(
            "Device:",
            DEVICE_ID
        )


        # ----------------------------------------------------
        # SEND TELEMETRY
        # ----------------------------------------------------

        for message_id in range(
            1,
            TOTAL_MESSAGES + 1
        ):

            # Generate telemetry
            telemetry = build_telemetry(
                message_id
            )


            # Display locally
            print_telemetry(
                telemetry
            )


            # Convert to Azure message
            message = create_azure_message(
                telemetry
            )


            # Send to Azure IoT Hub
            await device.send_message(
                message
            )


            print(
                "AZURE           : MESSAGE SENT SUCCESSFULLY"
            )


            # Wait before next sensor reading
            await asyncio.sleep(
                SEND_INTERVAL_SECONDS
            )


        print(
            "\n========================================"
        )

        print(
            "Simulation completed successfully."
        )


    # --------------------------------------------------------
    # ERROR HANDLING
    # --------------------------------------------------------

    except Exception as error:

        print("\nERROR:")

        print(error)


    # --------------------------------------------------------
    # DISCONNECT
    # --------------------------------------------------------

    finally:

        await device.shutdown()

        print(
            "\nDevice disconnected."
        )


# ============================================================
# RUN PROGRAM
# ============================================================

await main()
# Out:
# ========================================
#  SMART HOSPITAL IoT MONITORING SYSTEM
# ========================================
#
# Connecting to Azure IoT Hub...
# Connected: True
# Device: hospital-room-101
#
# ========================================
# MESSAGE ID      : 1
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:10.804699+00:00
# TEMPERATURE     : 26.7 °C
# HUMIDITY        : 49.1 %
# HEART RATE      : 93 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 2
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:14.080138+00:00
# TEMPERATURE     : 23.6 °C
# HUMIDITY        : 63.8 %
# HEART RATE      : 78 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 3
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:17.368874+00:00
# TEMPERATURE     : 26.2 °C
# HUMIDITY        : 64.7 %
# HEART RATE      : 68 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 4
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:20.656708+00:00
# TEMPERATURE     : 25.0 °C
# HUMIDITY        : 64.0 %
# HEART RATE      : 80 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 5
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:23.943097+00:00
# TEMPERATURE     : 23.5 °C
# HUMIDITY        : 77.2 %
# HEART RATE      : 82 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : ABNORMAL
# SYSTEM STATUS   : CRITICAL
# ALERT           : HIGH HUMIDITY
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 6
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:27.232385+00:00
# TEMPERATURE     : 26.2 °C
# HUMIDITY        : 46.9 %
# HEART RATE      : 91 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 7
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:30.507542+00:00
# TEMPERATURE     : 23.5 °C
# HUMIDITY        : 59.8 %
# HEART RATE      : 93 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 8
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:33.794348+00:00
# TEMPERATURE     : 25.2 °C
# HUMIDITY        : 53.8 %
# HEART RATE      : 94 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 9
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:37.083078+00:00
# TEMPERATURE     : 23.2 °C
# HUMIDITY        : 51.2 %
# HEART RATE      : 67 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 10
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:40.359534+00:00
# TEMPERATURE     : 32.3 °C
# HUMIDITY        : 47.7 %
# HEART RATE      : 74 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : ABNORMAL
# SYSTEM STATUS   : CRITICAL
# ALERT           : HIGH TEMPERATURE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 11
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:43.649019+00:00
# TEMPERATURE     : 24.7 °C
# HUMIDITY        : 50.0 %
# HEART RATE      : 89 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 12
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:46.928404+00:00
# TEMPERATURE     : 23.2 °C
# HUMIDITY        : 54.0 %
# HEART RATE      : 90 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 13
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:50.217163+00:00
# TEMPERATURE     : 24.7 °C
# HUMIDITY        : 57.4 %
# HEART RATE      : 94 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 14
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:53.495385+00:00
# TEMPERATURE     : 26.4 °C
# HUMIDITY        : 49.5 %
# HEART RATE      : 76 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 15
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T04:59:56.784577+00:00
# TEMPERATURE     : 26.4 °C
# HUMIDITY        : 72.6 %
# HEART RATE      : 68 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : ABNORMAL
# SYSTEM STATUS   : CRITICAL
# ALERT           : HIGH HUMIDITY
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 16
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T05:00:00.059086+00:00
# TEMPERATURE     : 26.4 °C
# HUMIDITY        : 60.9 %
# HEART RATE      : 68 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 17
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T05:00:03.399217+00:00
# TEMPERATURE     : 23.9 °C
# HUMIDITY        : 50.1 %
# HEART RATE      : 73 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 18
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T05:00:06.684761+00:00
# TEMPERATURE     : 23.5 °C
# HUMIDITY        : 48.1 %
# HEART RATE      : 75 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 19
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T05:00:09.978095+00:00
# TEMPERATURE     : 25.0 °C
# HUMIDITY        : 57.7 %
# HEART RATE      : 91 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : NORMAL
# SYSTEM STATUS   : NORMAL
# ALERT           : NONE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# MESSAGE ID      : 20
# ROOM            : Room-101
# TIMESTAMP       : 2026-09-03T05:00:13.263703+00:00
# TEMPERATURE     : 30.8 °C
# HUMIDITY        : 64.6 %
# HEART RATE      : 91 BPM
# BED STATUS      : occupied
# SIMULATION TYPE : ABNORMAL
# SYSTEM STATUS   : CRITICAL
# ALERT           : HIGH TEMPERATURE
# AZURE           : MESSAGE SENT SUCCESSFULLY
#
# ========================================
# Simulation completed successfully.
#
# Device disconnected.
